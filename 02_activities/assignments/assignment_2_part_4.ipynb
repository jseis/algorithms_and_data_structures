# %% [markdown]
# ## Part 4:
#
# Please write a 200 word reflection documenting your process from assignment 1, and your presentation and review experience with your partner at the bottom of the Jupyter Notebook under a new heading "Reflection." Again, export this Notebook as pdf.

# %% [markdown]
# ### Reflection

# %% [markdown]
# Before I began to code a solution to my assigned problem (#3) in Assignment 1, I created additional example inputs and manually evaluated the expected outcome. I tried to use those example inputs to address edge cases. Once I was confident that I had considered all edge cases, I started to consider a variety of approaches. I contemplated different data structures and similar structures to problems that I had seen before. Although this was a sorting problem, the binary alphabet it imposed seemed likely to make it easier than a general sorting problem. Compared to a baseline sorting algorithm of $O(nlogn)$, I realized that a queue could be employed to reduce the time complexity to linear at the cost of an increase of space complexity to $O(n)$. Once I wrote a solution and tested it against all inputs provided and created, I further analyzed correctness by writing a short inductive proof.
#
# I had written solutions to the other two assignment 1 problems for practice, so I had a reference for what a solution would look like before seeing my partner's submission. There were a couple stylistic differences between how my partner approached the problem and how I had. I liked the use of a dictionary for storing pairs of matching brackets.
